# %%
# Generate random number from interval (1, 10) TASK 1

user_input = input("What is your name")
print("Hello " + user_input , "think of a number between 1 and 10")
number = random.randint(1, 10) 

if guess == number:
    print("Well done " + user_input)
Else: 
    print("Incorrect, better luck next time")
# Out:
#   File "<ipython-input-76-bcef910cfc4f>", line 9
#     Else:
#           ^
# SyntaxError: invalid syntax

# %%
# Generate a program that asks the user for their favourite number TASK 2

user_input = input("What is your name?")
print("what is your favourite number between 1 and 100, " + user_input) 
number = random.randint(1, 100)

if favourite <= number  
    print("You have more hair on your knuckles than your head")
elif favourite >= number
    print("Punching a time clock is probably the most exercise you'll get all day")
else 
    print("Getting high means it's time to take your blood pressure medication")
# Out:
#   File "<ipython-input-100-2413bf0468b7>", line 7
#     if favourite_number <= 50
#                                ^
# SyntaxError: invalid syntax

# %%
# Generate program that allows user to enter their favourite starter, main, course, dessert and drink. TASK 3

print("What is your favourite starter?")
favourite_starter = input("What is your favourite starter?")
favourite_main = input("What is your favourite main?")
favourite_course = input("What is your favourite course?")
favourite_dessert = input("What is your favourite dessert?")
favourite_drink = input("What is your favourite drink?")
print("My favourite starter is " + favourite_starter, favourite_main, favourite_course, favourite_dessert, favourite_drink)
# Out:
# What is your favourite starter?
# My favourite starter is fjn fjgn rgnk rugn rugn

# %%
# TASK 4

value = 2000
while value > 1000:
    print("£", value)
    value = value * 0.999
# Out:
# £ 2000
# £ 1998.0
# £ 1996.002
# £ 1994.0059979999999
# £ 1992.011992002
# £ 1990.0199800099979
# £ 1988.029960029988
# £ 1986.041930069958
# £ 1984.055888139888
# £ 1982.0718322517482
# £ 1980.0897604194965
# £ 1978.109670659077
# £ 1976.131560988418
# £ 1974.1554294274295
# £ 1972.181273998002
# £ 1970.209092724004
# £ 1968.23888363128
# £ 1966.2706447476487
# £ 1964.304374102901
# £ 1962.340069728798
# £ 1960.3777296590692
# £ 1958.4173519294102
# £ 1956.4589345774807
# £ 1954.5024756429032
# £ 1952.5479731672604
# £ 1950.5954251940932
# £ 1948.6448297688992
# £ 1946.6961849391303
# £ 1944.7494887541911
# £ 1942.8047392654369
# £ 1940.8619345261714
# £ 1938.9210725916453
# £ 1936.9821515190536
# £ 1935.0451693675345
# £ 1933.110124198167
# £ 1931.1770140739686
# £ 1929.2458370598947
# £ 1927.3165912228349
# £ 1925.3892746316121
# £ 1923.4638853569804
# £ 1921.5404214716234
# £ 1919.6188810501517
# £ 1917.6992621691015
# £ 1915.7815629069323
# £ 1913.8657813440254
# ...

# %%
# TASK 5

user_input1 = input("Enter first number")
user_input2 = input("Enter second number") 

print("Enter which operation you like")
